# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("1.5.csv")
data
# Out:
#      Year  Historical     y2010     y2011     y2012     y2013     y2014  \
# 0    2000   29.379836       NaN       NaN       NaN       NaN       NaN
# 1    2001   29.453605       NaN       NaN       NaN       NaN       NaN
# 2    2002   30.397202       NaN       NaN       NaN       NaN       NaN
# 3    2003   31.948771       NaN       NaN       NaN       NaN       NaN
# 4    2004   33.083227       NaN       NaN       NaN       NaN       NaN
# ..    ...         ...       ...       ...       ...       ...       ...
# 96   2096         NaN  0.017333  0.008932  0.003467  0.002145  0.001091
# 97   2097         NaN  0.015542  0.007929  0.003035  0.001863  0.000938
# 98   2098         NaN  0.013935  0.007038  0.002656  0.001618  0.000807
# 99   2099         NaN  0.012493  0.006246  0.002324  0.001405  0.000693
# 100  2100         NaN  0.011199  0.005543  0.002033  0.001220  0.000596
#
#         y2015     y2016     y2017     y2018     y2019  y2020  y2021  y2022  \
# ...

# %%
x = plt.figure(figsize=(10,8))
plt.plot(range(1,102),data.Historical, linewidth=3.0, c='black', label = 'Historic')
plt.plot(range(1,102),data.y2010, linewidth=1, c='maroon', label = '2010')
plt.plot(range(1,102),data.y2011, linewidth=1, c='red', label = '2011')
plt.plot(range(1,102),data.y2012, linewidth=1, c='orangered', label = '2012')
plt.plot(range(1,102),data.y2013, linewidth=1, c='salmon', label = '2013')
plt.plot(range(1,102),data.y2014, linewidth=1, c='salmon', label = '2014')
plt.plot(range(1,102),data.y2015, linewidth=1, c='papayawhip', label = '2015')
plt.plot(range(1,102),data.y2016, linewidth=1.0, c='peachpuff', label = '2016')
plt.plot(range(1,102),data.y2017, linewidth=1.0, c='mistyrose', label = '2017')
plt.plot(range(1,102),data.y2018, linewidth=1.0, c='peachpuff', label = '2018')
plt.plot(range(1,102),data.y2019, linewidth=1, c='dimGray', label = '2019')
plt.plot(range(1,102),data.y2020, linewidth=1.0, c='lavender', label = '2020')
plt.plot(range(1,102),data.y2021, linewidth=1.0, c='powderblue', label = '2021')
plt.plot(range(1,102),data.y2022, linewidth=1.0, c='lightskyblue', label = '2022')
plt.plot(range(1,102),data.y2023, linewidth=1.0, c='deepskyblue', label = '2023')
plt.plot(range(1,102),data.y2024, linewidth=1.0, c='royalblue', label = '2024')
plt.plot(range(1,102),data.y2025, linewidth=1.0, c='blue', label = '2025')
plt.plot(range(1,102),data.y2026, linewidth=1.0, c='darkBlue', label = '2026')
plt.xticks(range(1,102,10),[2000,2010,2020,2030,2040,2050,2060,2070,2080,2090,2100])
plt.xlabel('Year', fontsize=12)
plt.ylabel('$\mathregular{CO^{2}}$ emissions from fossil fuels\nand land-use (Gt $\mathregular{CO^{2}}$/yr)', fontsize=12, multialignment='center')
plt.axes().yaxis.grid(c='black',alpha=0.2)
plt.legend(loc='upper right')


        
plt.yticks(np.arange(0, 50,5))

plt.show()
x.savefig('1.5degree.png')
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
data2 = pd.read_csv("2.csv")
data2
# Out:
#      Year  Historical     y2010     y2011     y2012     y2013     y2014  \
# 0    2000   29.379836       NaN       NaN       NaN       NaN       NaN
# 1    2001   29.453605       NaN       NaN       NaN       NaN       NaN
# 2    2002   30.397202       NaN       NaN       NaN       NaN       NaN
# 3    2003   31.948771       NaN       NaN       NaN       NaN       NaN
# 4    2004   33.083227       NaN       NaN       NaN       NaN       NaN
# ..    ...         ...       ...       ...       ...       ...       ...
# 96   2096         NaN  1.457140  1.226222  0.927745  0.921749  0.885729
# 97   2097         NaN  1.382287  1.159318  0.872491  0.866552  0.831963
# 98   2098         NaN  1.311143  1.095947  0.820437  0.814569  0.781371
# 99   2099         NaN  1.243534  1.035931  0.771404  0.765620  0.733773
# 100  2100         NaN  1.179295  0.979102  0.725224  0.719534  0.688999
#
#         y2015     y2016     y2017  ...     y2019     y2020     y2021  \
# ...

# %%
y = plt.figure(figsize=(10,8))
plt.plot(range(1,102),data2.Historical, linewidth=3.0, c='black', label = 'Historic')
plt.plot(range(1,102),data2.y2010, linewidth=1, c='maroon', label = '2010')
plt.plot(range(1,102),data2.y2011, linewidth=1, c='red', label = '2011')
plt.plot(range(1,102),data2.y2012, linewidth=1, c='orangered', label = '2012')
plt.plot(range(1,102),data2.y2013, linewidth=1, c='salmon', label = '2013')
plt.plot(range(1,102),data2.y2014, linewidth=1, c='salmon', label = '2014')
plt.plot(range(1,102),data2.y2015, linewidth=1, c='papayawhip', label = '2015')
plt.plot(range(1,102),data2.y2016, linewidth=1.0, c='peachpuff', label = '2016')
plt.plot(range(1,102),data2.y2017, linewidth=1.0, c='mistyrose', label = '2017')
plt.plot(range(1,102),data2.y2018, linewidth=1.0, c='peachpuff', label = '2018')
plt.plot(range(1,102),data2.y2019, linewidth=1, c='dimGray', label = '2019')
plt.plot(range(1,102),data2.y2020, linewidth=1.0, c='lavender', label = '2020')
plt.plot(range(1,102),data2.y2021, linewidth=1.0, c='powderblue', label = '2021')
plt.plot(range(1,102),data2.y2022, linewidth=1.0, c='lightskyblue', label = '2022')
plt.plot(range(1,102),data2.y2023, linewidth=1.0, c='lightskyblue', label = '2023')
plt.plot(range(1,102),data2.y2024, linewidth=1.0, c='deepskyblue', label = '2024')
plt.plot(range(1,102),data2.y2025, linewidth=1.0, c='deepskyblue', label = '2025')
plt.plot(range(1,102),data2.y2026, linewidth=1.0, c='royalblue', label = '2026')
plt.plot(range(1,102),data2.y2027, linewidth=1.0, c='blue', label = '2027')
plt.plot(range(1,102),data2.y2028, linewidth=1.0, c='darkBlue', label = '2028')
plt.xticks(range(1,102,10),[2000,2010,2020,2030,2040,2050,2060,2070,2080,2090,2100])
plt.xlabel('Year', fontsize=12)
plt.ylabel('$\mathregular{CO^{2}}$ emissions from fossil fuels\nand land-use (Gt $\mathregular{CO^{2}}$/yr)', fontsize=12)
plt.axes().yaxis.grid(c='black',alpha=0.2)
plt.legend(loc='upper right')


        
plt.yticks(np.arange(0, 50,5))

plt.show()
y.savefig('2degree.png')
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
